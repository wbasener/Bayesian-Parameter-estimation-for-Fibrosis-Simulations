# %%
import pandas as pd 
import numpy as np 
from matplotlib import pyplot as plt
from skopt.plots import plot_objective
import NLmodel_ParameterSampling_minimization

import importlib
importlib.reload(NLmodel_ParameterSampling_minimization);

# %%
sim = NLmodel_ParameterSampling_minimization.simulation(n_calls=100, fname_NL_model = './Pulmonary_Histology_5_20_2024_Bill.nlogo')

# %%
result = sim.sampling_minimization()
# Out:
# time=33.65, statistic=9.24, coldep=180.12, coldeg=34.54, transition_threshold = 0.17
# time=52.21, statistic=52.18, coldep=121.81, coldeg=119.51, transition_threshold = 0.03
# time=73.48, statistic=42.54, coldep=44.9, coldeg=139.68, transition_threshold = 0.18
# time=96.75, statistic=13.34, coldep=126.59, coldeg=1.03, transition_threshold = 0.11
# time=118.6, statistic=56.0, coldep=72.3, coldeg=120.83, transition_threshold = 0.08
# time=139.74, statistic=56.0, coldep=162.39, coldeg=122.51, transition_threshold = 0.05
# time=159.73, statistic=56.0, coldep=128.78, coldeg=162.21, transition_threshold = 0.0
# time=179.52, statistic=56.0, coldep=7.96, coldeg=189.0, transition_threshold = 0.09
# time=199.67, statistic=52.18, coldep=88.27, coldeg=13.14, transition_threshold = 0.04
# time=220.69, statistic=39.82, coldep=173.18, coldeg=168.71, transition_threshold = 0.19
# time=243.14, statistic=8.99, coldep=198.13, coldeg=15.28, transition_threshold = 0.18
# time=265.81, statistic=8.8, coldep=196.12, coldeg=11.03, transition_threshold = 0.17
# time=289.1, statistic=10.84, coldep=189.25, coldeg=9.64, transition_threshold = 0.14
# time=315.06, statistic=13.34, coldep=196.29, coldeg=6.43, transition_threshold = 0.1
# time=344.67, statistic=10.84, coldep=186.93, coldeg=15.93, transition_threshold = 0.14
# time=371.15, statistic=25.57, coldep=198.33, coldeg=2.51, transition_threshold = 0.08
# time=403.74, statistic=9.56, coldep=166.2, coldeg=17.51, transition_threshold = 0.17
# time=433.42, statistic=9.56, coldep=123.87, coldeg=16.57, transition_threshold = 0.17
# time=458.25, statistic=10.36, coldep=49.71, coldeg=15.02, transition_threshold = 0.17
# time=481.59, statistic=9.93, coldep=191.27, coldeg=45.39, transition_threshold = 0.17
# time=505.1, statistic=9.56, coldep=70.06, coldeg=37.01, transition_threshold = 0.17
# time=528.53, statistic=10.36, coldep=186.58, coldeg=53.58, transition_threshold = 0.17
# time=549.32, statistic=11.98, coldep=188.86, coldeg=62.91, transition_threshold = 0.17
# time=570.23, statistic=45.48, coldep=44.93, coldeg=54.79, transition_threshold = 0.17
# time=591.15, statistic=11.98, coldep=112.41, coldeg=21.18, transition_threshold = 0.14
# time=613.46, statistic=8.99, coldep=77.42, coldeg=10.61, transition_threshold = 0.16
# time=633.88, statistic=11.38, coldep=63.84, coldeg=12.81, transition_threshold = 0.16
# time=656.86, statistic=11.38, coldep=81.82, coldeg=35.99, transition_threshold = 0.15
# time=679.31, statistic=52.18, coldep=18.6, coldeg=15.84, transition_threshold = 0.17
# time=702.4, statistic=9.56, coldep=95.04, coldeg=17.74, transition_threshold = 0.17
# time=725.88, statistic=9.24, coldep=98.36, coldeg=23.35, transition_threshold = 0.17
# time=749.24, statistic=9.24, coldep=95.63, coldeg=10.86, transition_threshold = 0.17
# time=772.36, statistic=9.56, coldep=91.81, coldeg=15.16, transition_threshold = 0.17
# time=796.89, statistic=8.64, coldep=93.54, coldeg=16.5, transition_threshold = 0.18
# time=822.32, statistic=9.56, coldep=87.78, coldeg=18.02, transition_threshold = 0.19
# time=845.95, statistic=8.8, coldep=77.91, coldeg=14.13, transition_threshold = 0.18
# time=868.94, statistic=9.24, coldep=65.72, coldeg=16.23, transition_threshold = 0.17
# time=892.9, statistic=8.99, coldep=68.95, coldeg=16.11, transition_threshold = 0.17
# time=915.44, statistic=9.93, coldep=54.39, coldeg=10.93, transition_threshold = 0.17
# time=940.29, statistic=9.56, coldep=56.54, coldeg=13.89, transition_threshold = 0.17
# time=963.88, statistic=9.71, coldep=51.85, coldeg=13.54, transition_threshold = 0.19
# time=987.21, statistic=8.8, coldep=49.99, coldeg=16.44, transition_threshold = 0.19
# time=1010.56, statistic=48.69, coldep=14.45, coldeg=16.38, transition_threshold = 0.19
# time=1035.52, statistic=9.24, coldep=61.45, coldeg=17.76, transition_threshold = 0.18
# time=1061.27, statistic=8.75, coldep=62.57, coldeg=16.79, transition_threshold = 0.19
# time=1085.76, statistic=9.24, coldep=56.38, coldeg=16.03, transition_threshold = 0.19
# time=1110.99, statistic=13.22, coldep=53.76, coldeg=15.79, transition_threshold = 0.19
# time=1135.3, statistic=10.36, coldep=49.74, coldeg=14.2, transition_threshold = 0.17
# time=1161.12, statistic=9.93, coldep=51.49, coldeg=15.52, transition_threshold = 0.17
# time=1186.01, statistic=8.8, coldep=51.62, coldeg=17.4, transition_threshold = 0.18
# time=1211.47, statistic=12.63, coldep=46.58, coldeg=18.5, transition_threshold = 0.17
# time=1233.75, statistic=56.0, coldep=2.94, coldeg=8.23, transition_threshold = 0.18
# time=1259.23, statistic=9.56, coldep=47.54, coldeg=8.39, transition_threshold = 0.18
# time=1285.15, statistic=9.93, coldep=46.28, coldeg=8.65, transition_threshold = 0.18
# time=1310.94, statistic=8.8, coldep=70.39, coldeg=8.1, transition_threshold = 0.18
# time=1336.62, statistic=9.93, coldep=42.31, coldeg=7.32, transition_threshold = 0.18
# time=1363.44, statistic=11.38, coldep=38.03, coldeg=2.43, transition_threshold = 0.17
# time=1388.65, statistic=10.36, coldep=37.69, coldeg=8.13, transition_threshold = 0.18
# time=1414.98, statistic=9.93, coldep=38.91, coldeg=9.12, transition_threshold = 0.2
# time=1441.87, statistic=11.98, coldep=34.55, coldeg=10.26, transition_threshold = 0.18
# time=1468.16, statistic=9.56, coldep=35.71, coldeg=7.94, transition_threshold = 0.19
# time=1495.01, statistic=10.36, coldep=34.56, coldeg=7.17, transition_threshold = 0.18
# time=1519.87, statistic=11.98, coldep=31.41, coldeg=8.05, transition_threshold = 0.19
# time=1545.15, statistic=11.38, coldep=32.63, coldeg=7.1, transition_threshold = 0.16
# time=1572.5, statistic=11.38, coldep=31.55, coldeg=9.06, transition_threshold = 0.16
# time=1598.15, statistic=11.98, coldep=31.19, coldeg=13.66, transition_threshold = 0.18
# time=1623.15, statistic=45.48, coldep=34.97, coldeg=28.92, transition_threshold = 0.18
# time=1648.1, statistic=11.98, coldep=28.46, coldeg=10.69, transition_threshold = 0.19
# time=1675.85, statistic=12.63, coldep=26.62, coldeg=10.17, transition_threshold = 0.19
# time=1701.44, statistic=10.36, coldep=57.79, coldeg=27.07, transition_threshold = 0.18
# time=1728.02, statistic=12.63, coldep=26.67, coldeg=6.08, transition_threshold = 0.15
# time=1751.96, statistic=11.38, coldep=27.15, coldeg=7.2, transition_threshold = 0.18
# time=1780.07, statistic=8.64, coldep=68.28, coldeg=30.87, transition_threshold = 0.19
# time=1805.15, statistic=11.38, coldep=27.85, coldeg=8.41, transition_threshold = 0.18
# time=1832.2, statistic=9.56, coldep=70.21, coldeg=37.26, transition_threshold = 0.18
# time=1857.71, statistic=8.8, coldep=60.41, coldeg=30.13, transition_threshold = 0.19
# time=1887.47, statistic=12.63, coldep=67.07, coldeg=46.16, transition_threshold = 0.19
# time=1918.47, statistic=14.1, coldep=42.0, coldeg=28.08, transition_threshold = 0.19
# time=1948.22, statistic=13.34, coldep=77.86, coldeg=34.41, transition_threshold = 0.13
# time=1977.82, statistic=8.75, coldep=99.91, coldeg=51.9, transition_threshold = 0.19
# time=2007.33, statistic=12.63, coldep=93.05, coldeg=59.96, transition_threshold = 0.2
# time=2038.21, statistic=10.84, coldep=193.63, coldeg=65.9, transition_threshold = 0.17
# time=2068.5, statistic=10.84, coldep=96.34, coldeg=50.31, transition_threshold = 0.15
# time=2098.33, statistic=12.63, coldep=24.92, coldeg=2.86, transition_threshold = 0.2
# time=2126.62, statistic=10.36, coldep=196.77, coldeg=77.73, transition_threshold = 0.17
# time=2154.46, statistic=9.93, coldep=193.99, coldeg=82.45, transition_threshold = 0.16
# time=2181.38, statistic=11.38, coldep=193.57, coldeg=86.07, transition_threshold = 0.14
# time=2211.66, statistic=10.84, coldep=193.16, coldeg=98.02, transition_threshold = 0.17
# time=2237.67, statistic=12.63, coldep=198.06, coldeg=87.54, transition_threshold = 0.12
# time=2264.74, statistic=52.18, coldep=120.16, coldeg=89.3, transition_threshold = 0.16
# time=2293.08, statistic=11.38, coldep=119.09, coldeg=46.74, transition_threshold = 0.17
# time=2322.76, statistic=10.84, coldep=120.06, coldeg=49.11, transition_threshold = 0.17
# time=2348.95, statistic=10.84, coldep=104.9, coldeg=67.08, transition_threshold = 0.17
# time=2378.37, statistic=13.34, coldep=105.37, coldeg=68.96, transition_threshold = 0.17
# time=2405.3, statistic=12.63, coldep=187.87, coldeg=80.73, transition_threshold = 0.12
# time=2431.65, statistic=11.38, coldep=24.62, coldeg=8.81, transition_threshold = 0.17
# time=2459.75, statistic=10.84, coldep=196.29, coldeg=104.24, transition_threshold = 0.15
# time=2487.55, statistic=11.98, coldep=23.7, coldeg=2.26, transition_threshold = 0.18
# time=2514.21, statistic=24.04, coldep=23.7, coldeg=9.82, transition_threshold = 0.17
# time=2541.85, statistic=10.36, coldep=181.69, coldeg=93.86, transition_threshold = 0.16

# %%
_ = plot_objective(result, n_points=150)
plt.savefig('partial_dpendence_RF')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 _ = plot_objective(result, n_points=150)
# ----> 2 plt.savefig('partial_dpendence_RF')
#
# NameError: name 'plt' is not defined

# %%
plt.savefig('partial_dpendence_RF')
