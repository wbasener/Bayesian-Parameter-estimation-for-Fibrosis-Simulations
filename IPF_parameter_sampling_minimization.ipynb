# %%
import pandas as pd 
import numpy as np 
from matplotlib import pyplot as plt
from skopt.plots import plot_objective
import NLmodel_ParameterSampling_minimization
# Out:
# skopt version: 0.10.1
# sklearn version: 1.3.2

# %%
# for easy re-importing if changes were made to NLmodel_ParameterSampling_minimization.py
#import importlib
#importlib.reload(NLmodel_ParameterSampling_minimization);

# %%
sim = NLmodel_ParameterSampling_minimization.simulation(n_calls=100, fname_NL_model = './Pulmonary_Histology_6_19_2024_Bill.nlogo')

# %%
result = sim.sampling_minimization()
# Out:
# time=18.92, statistic=1.47, coldep=180.12, coldeg=34.54, transition_threshold = 0.17
# time=38.13, statistic=56.0, coldep=121.81, coldeg=119.51, transition_threshold = 0.03
# time=59.1, statistic=48.69, coldep=44.9, coldeg=139.68, transition_threshold = 0.18
# time=83.66, statistic=12.63, coldep=126.59, coldeg=1.03, transition_threshold = 0.11
# time=103.13, statistic=56.0, coldep=72.3, coldeg=120.83, transition_threshold = 0.08
# time=127.76, statistic=56.0, coldep=162.39, coldeg=122.51, transition_threshold = 0.05
# time=149.49, statistic=56.0, coldep=128.78, coldeg=162.21, transition_threshold = 0.0
# time=171.37, statistic=56.0, coldep=7.96, coldeg=189.0, transition_threshold = 0.09
# time=194.51, statistic=52.18, coldep=88.27, coldeg=13.14, transition_threshold = 0.04
# time=214.74, statistic=45.48, coldep=173.18, coldeg=168.71, transition_threshold = 0.19
# time=241.11, statistic=14.76, coldep=198.13, coldeg=15.28, transition_threshold = 0.18
# ...

# %%
_ = plot_objective(result, n_points=150)
plt.savefig('partial_dpendence_RF')

# %%
plt.savefig('partial_dpendence_RF')
