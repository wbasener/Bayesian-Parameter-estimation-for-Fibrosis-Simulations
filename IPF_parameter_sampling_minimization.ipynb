# %%
import pandas as pd 
import numpy as np 
from matplotlib import pyplot as plt
from skopt.plots import plot_objective
import NLmodel_ParameterSampling_minimization

# %%
# for easy re-importing if changes were made to NLmodel_ParameterSampling_minimization.py
#import importlib
#importlib.reload(NLmodel_ParameterSampling_minimization);

# %%
sim = NLmodel_ParameterSampling_minimization.simulation(n_calls=500, fname_NL_model = './Pulmonary_Histology_6_19_2024_Bill.nlogo')

# %%
result = sim.sampling_minimization()
# Out:
# time=36.78, statistic=11.05, coldep=180.12, coldeg=34.54, transition_threshold = 0.17
# time=56.56, statistic=56.0, coldep=121.81, coldeg=119.51, transition_threshold = 0.03
# time=72.77, statistic=48.69, coldep=44.9, coldeg=139.68, transition_threshold = 0.18
# time=95.17, statistic=12.63, coldep=126.59, coldeg=1.03, transition_threshold = 0.11
# time=114.91, statistic=56.0, coldep=72.3, coldeg=120.83, transition_threshold = 0.08
# time=135.3, statistic=56.0, coldep=162.39, coldeg=122.51, transition_threshold = 0.05
# time=153.58, statistic=56.0, coldep=128.78, coldeg=162.21, transition_threshold = 0.0
# time=171.01, statistic=56.0, coldep=7.96, coldeg=189.0, transition_threshold = 0.09
# time=191.82, statistic=45.48, coldep=88.27, coldeg=13.14, transition_threshold = 0.04
# time=211.22, statistic=52.18, coldep=173.18, coldeg=168.71, transition_threshold = 0.19
# time=235.58, statistic=22.4, coldep=157.53, coldeg=10.04, transition_threshold = 0.2
# time=256.66, statistic=10.84, coldep=174.16, coldeg=30.43, transition_threshold = 0.14
# time=279.81, statistic=11.98, coldep=194.92, coldeg=28.21, transition_threshold = 0.13
# time=300.11, statistic=56.0, coldep=186.09, coldeg=37.33, transition_threshold = 0.1
# time=321.96, statistic=10.84, coldep=187.01, coldeg=31.04, transition_threshold = 0.14
# time=343.43, statistic=9.56, coldep=183.54, coldeg=33.43, transition_threshold = 0.14
# time=365.4, statistic=11.98, coldep=190.88, coldeg=35.39, transition_threshold = 0.14
# time=388.23, statistic=9.56, coldep=192.51, coldeg=35.41, transition_threshold = 0.14
# time=409.28, statistic=17.79, coldep=193.62, coldeg=46.91, transition_threshold = 0.14
# time=430.59, statistic=14.1, coldep=181.58, coldeg=35.57, transition_threshold = 0.13
# time=452.48, statistic=12.63, coldep=186.9, coldeg=33.91, transition_threshold = 0.12
# time=474.55, statistic=13.34, coldep=184.84, coldeg=29.7, transition_threshold = 0.11
# time=495.8, statistic=11.98, coldep=185.17, coldeg=34.9, transition_threshold = 0.11
# time=517.61, statistic=27.2, coldep=184.54, coldeg=37.74, transition_threshold = 0.11
# time=540.82, statistic=11.98, coldep=198.55, coldeg=30.48, transition_threshold = 0.1
# time=563.31, statistic=14.93, coldep=189.63, coldeg=51.2, transition_threshold = 0.14
# time=585.45, statistic=11.98, coldep=195.26, coldeg=29.06, transition_threshold = 0.09
# time=607.56, statistic=17.79, coldep=199.08, coldeg=29.96, transition_threshold = 0.07
# time=655.79, statistic=14.1, coldep=184.66, coldeg=55.49, transition_threshold = 0.16
# time=761.74, statistic=13.34, coldep=182.82, coldeg=33.63, transition_threshold = 0.1
# time=867.31, statistic=20.04, coldep=189.32, coldeg=30.72, transition_threshold = 0.06
# time=3832.58, statistic=16.77, coldep=197.92, coldeg=63.4, transition_threshold = 0.13
# time=3909.28, statistic=15.81, coldep=128.93, coldeg=33.83, transition_threshold = 0.14
# time=3978.64, statistic=12.63, coldep=171.9, coldeg=30.28, transition_threshold = 0.11
# time=4081.29, statistic=48.69, coldep=176.5, coldeg=42.06, transition_threshold = 0.1
# time=4195.97, statistic=9.56, coldep=173.02, coldeg=32.83, transition_threshold = 0.14
# time=4282.89, statistic=11.98, coldep=180.45, coldeg=33.54, transition_threshold = 0.1
# time=4376.3, statistic=11.38, coldep=187.44, coldeg=31.75, transition_threshold = 0.1
# time=4475.27, statistic=12.63, coldep=178.59, coldeg=34.22, transition_threshold = 0.1
# time=4587.33, statistic=32.82, coldep=170.78, coldeg=33.43, transition_threshold = 0.1
# time=4685.7, statistic=11.38, coldep=173.76, coldeg=34.31, transition_threshold = 0.17
# time=4775.56, statistic=14.1, coldep=98.36, coldeg=30.07, transition_threshold = 0.13
# time=4868.64, statistic=56.0, coldep=13.79, coldeg=29.84, transition_threshold = 0.13
# time=4937.08, statistic=16.77, coldep=153.64, coldeg=31.6, transition_threshold = 0.13
# time=5013.83, statistic=52.18, coldep=186.46, coldeg=37.1, transition_threshold = 0.14
# time=5090.46, statistic=10.36, coldep=185.89, coldeg=25.03, transition_threshold = 0.14
# time=5170.98, statistic=9.56, coldep=187.05, coldeg=33.65, transition_threshold = 0.14
# time=5271.55, statistic=14.1, coldep=175.7, coldeg=36.92, transition_threshold = 0.14
# time=5364.08, statistic=12.63, coldep=188.08, coldeg=36.8, transition_threshold = 0.16

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = (12,8)
_ = plot_objective(result, n_points=500)
plt.savefig('partial_dpendence_RF')

# %%
plt.savefig('partial_dpendence_RF')
